# %%
import torch
import pandas as pd
import numpy as np
from ga_optimizer  import GA_optimizer

# %%
class Args:
    def __init__(self):
        self.lambda_ = 0.1  # 초기값
        self.learning_rate = 0.01  # 초기값
        self.batch_size = 32  # 초기값
        self.num_layers = 2  # 초기값

args = Args()

# %%
def train_func(args):
    # args 객체를 사용하여 모델 훈련 및 F1 점수 계산
    print(f"Training with: lambda={args.lambda_}, lr={args.learning_rate}, "
          f"batch_size={args.batch_size}, num_layers={args.num_layers}")
    return np.random.uniform(0.5, 2.0)  # F1 점수를 랜덤으로 반환 (예시)

# GA 설정
GA_parameter = {
    "population_size": 3,
    "generation": 5,
    "crossover_rate": 0.8,
    "mutation_rate": 0.1
}

# 하이퍼파라미터 범위와 이름
hyperparameters = [
    np.arange(0, 0.3, 0.05),  # 학습률
    np.arange(0.006, 0.012, 0.0001 ),       # 배치 크기
    np.arange(0.01, 0.05, 0.005)            # 층 수
]

hyperparameter_names = ["learning_rate", "batch_size", "num_layers"]

# GA 최적화 실행
best_f1, best_chromosome = GA_optimizer(args, GA_parameter, train_func, hyperparameters, hyperparameter_names)

print("Best F1:", best_f1)
print("Best Hyperparameters:", best_chromosome)
# Out:
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.15, batch_size=0.0094, num_layers=0.01
# Training with: lambda=0.1, lr=0.25, batch_size=0.0083, num_layers=0.045
# Generation 0: Best F1 Score = 1.4427
# Generation 0 Population: [[0.0, 0.0065, 0.02], [0.0, 0.0065, 0.02], [0.15, 0.0094, 0.01]]
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.15, batch_size=0.0094, num_layers=0.01
# Generation 1: Best F1 Score = 1.2135
# Generation 1 Population: [[0.0, 0.0065, 0.02], [0.0, 0.0065, 0.02], [0.0, 0.0065, 0.02]]
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Generation 2: Best F1 Score = 1.3753
# Generation 2 Population: [[0.0, 0.0065, 0.02], [0.0, 0.0065, 0.02], [0.0, 0.0113, 0.02]]
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.02
# Generation 3: Best F1 Score = 1.9862
# Generation 3 Population: [[0.0, 0.0113, 0.02], [0.0, 0.0065, 0.02], [0.0, 0.0113, 0.02]]
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.02
# Generation 4: Best F1 Score = 1.4574
# Generation 4 Population: [[0.0, 0.0113, 0.02], [0.0, 0.0113, 0.02], [0.0, 0.0113, 0.02]]
# Best F1: 1.9862245558176226
# Best Hyperparameters: [0.0, 0.0065, 0.02]

# %%
from pso_optimizer import pso_optimizer
from random_search import random_search
from grid_search import grid_search
# PSO
pso_params = {
    "num_particles": 10,
    "num_iterations": 20,
    "inertia_weight": 0.5,
    "cognitive_coeff": 1.5,
    "social_coeff": 1.5,
}

best_f1, best_params = grid_search(args, train_func, hyperparameters, hyperparameter_names)

best_f1, best_params = pso_optimizer(args, train_func, hyperparameters, hyperparameter_names, pso_params)
print("PSO - Best F1:", best_f1, "Params:", best_params)

# Random Search
best_f1, best_params = random_search(args, train_func, hyperparameters, hyperparameter_names, num_samples=50)
print("Random Search - Best F1:", best_f1, "Params:", best_params)
# Out:
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.006, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0061, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0062, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0063, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0064, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0065, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0066, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0067, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0068, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0069, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0071, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0073, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0074, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0075, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0076, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0078, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0079, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.008, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0081, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0082, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0083, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0084, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0085, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0086, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0087, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0088, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0089, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.009, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0091, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0093, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0094, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0095, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0097, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0098, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0099, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.01, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0103, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0105, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0106, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0107, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0108, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0109, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0111, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0112, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0115, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0116, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0118, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.01
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0119, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.006, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0061, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0063, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0064, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0065, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0066, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0067, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0068, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0069, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.007, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0071, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0073, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0074, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0078, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0079, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.008, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0081, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0083, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0084, num_layers=0.04
# ...
# Training with: lambda=0.1, lr=0.209122, batch_size=0.009735, num_layers=0.013403
# Training with: lambda=0.1, lr=0.2, batch_size=0.0097, num_layers=0.015
# Training with: lambda=0.1, lr=0.209458, batch_size=0.009444, num_layers=0.016153
# Training with: lambda=0.1, lr=0.2, batch_size=0.0097, num_layers=0.016653
# Training with: lambda=0.1, lr=0.202638, batch_size=0.009137, num_layers=0.01
# Training with: lambda=0.1, lr=0.2, batch_size=0.009984, num_layers=0.013685
# Training with: lambda=0.1, lr=0.200921, batch_size=0.01036, num_layers=0.016773
# Training with: lambda=0.1, lr=0.197478, batch_size=0.009606, num_layers=0.012432
# Training with: lambda=0.1, lr=0.209025, batch_size=0.010184, num_layers=0.015
# Training with: lambda=0.1, lr=0.210774, batch_size=0.009678, num_layers=0.015
# Training with: lambda=0.1, lr=0.196538, batch_size=0.009699, num_layers=0.014924
# Training with: lambda=0.1, lr=0.2, batch_size=0.0097, num_layers=0.015
# Training with: lambda=0.1, lr=0.215967, batch_size=0.009236, num_layers=0.015517
# Training with: lambda=0.1, lr=0.2, batch_size=0.0097, num_layers=0.015526
# Training with: lambda=0.1, lr=0.20467, batch_size=0.009757, num_layers=0.017287
# Training with: lambda=0.1, lr=0.2, batch_size=0.009425, num_layers=0.015985
# Training with: lambda=0.1, lr=0.190241, batch_size=0.010007, num_layers=0.015104
# Training with: lambda=0.1, lr=0.202798, batch_size=0.00975, num_layers=0.015451
# Training with: lambda=0.1, lr=0.202877, batch_size=0.010208, num_layers=0.015
# Training with: lambda=0.1, lr=0.198282, batch_size=0.009688, num_layers=0.015
# Training with: lambda=0.1, lr=0.190545, batch_size=0.009682, num_layers=0.015769
# Training with: lambda=0.1, lr=0.2, batch_size=0.0097, num_layers=0.015
# Training with: lambda=0.1, lr=0.203007, batch_size=0.009752, num_layers=0.014731
# Training with: lambda=0.1, lr=0.203811, batch_size=0.009745, num_layers=0.01476
# Training with: lambda=0.1, lr=0.204447, batch_size=0.010066, num_layers=0.017602
# Training with: lambda=0.1, lr=0.200797, batch_size=0.009313, num_layers=0.016692
# Training with: lambda=0.1, lr=0.193725, batch_size=0.009641, num_layers=0.014218
# Training with: lambda=0.1, lr=0.205547, batch_size=0.009824, num_layers=0.016197
# Training with: lambda=0.1, lr=0.19983, batch_size=0.00981, num_layers=0.014996
# Training with: lambda=0.1, lr=0.197214, batch_size=0.00976, num_layers=0.014992
# Training with: lambda=0.1, lr=0.201702, batch_size=0.009769, num_layers=0.015904
# Training with: lambda=0.1, lr=0.204407, batch_size=0.009773, num_layers=0.014634
# Training with: lambda=0.1, lr=0.196527, batch_size=0.01001, num_layers=0.014338
# Training with: lambda=0.1, lr=0.19649, batch_size=0.009834, num_layers=0.014018
# Training with: lambda=0.1, lr=0.196245, batch_size=0.010141, num_layers=0.015322
# Training with: lambda=0.1, lr=0.195602, batch_size=0.010021, num_layers=0.0153
# Training with: lambda=0.1, lr=0.196495, batch_size=0.009621, num_layers=0.013868
# Training with: lambda=0.1, lr=0.196478, batch_size=0.010046, num_layers=0.015907
# Training with: lambda=0.1, lr=0.195835, batch_size=0.009907, num_layers=0.014347
# Training with: lambda=0.1, lr=0.195722, batch_size=0.00988, num_layers=0.014067
# Training with: lambda=0.1, lr=0.207198, batch_size=0.010151, num_layers=0.015084
# Training with: lambda=0.1, lr=0.194892, batch_size=0.010037, num_layers=0.014429
# Training with: lambda=0.1, lr=0.193287, batch_size=0.010139, num_layers=0.014142
# Training with: lambda=0.1, lr=0.190824, batch_size=0.009958, num_layers=0.013765
# Training with: lambda=0.1, lr=0.188006, batch_size=0.010178, num_layers=0.012644
# Training with: lambda=0.1, lr=0.189905, batch_size=0.010531, num_layers=0.012948
# Training with: lambda=0.1, lr=0.194417, batch_size=0.010141, num_layers=0.01374
# Training with: lambda=0.1, lr=0.188047, batch_size=0.010199, num_layers=0.015612
# Training with: lambda=0.1, lr=0.190723, batch_size=0.010261, num_layers=0.013865
# Training with: lambda=0.1, lr=0.194457, batch_size=0.010165, num_layers=0.013619
# Training with: lambda=0.1, lr=0.20155, batch_size=0.01033, num_layers=0.01333
# Training with: lambda=0.1, lr=0.188009, batch_size=0.010303, num_layers=0.014094
# Training with: lambda=0.1, lr=0.191667, batch_size=0.010203, num_layers=0.014044
# Training with: lambda=0.1, lr=0.188343, batch_size=0.010219, num_layers=0.014003
# Training with: lambda=0.1, lr=0.188898, batch_size=0.010223, num_layers=0.01329
# Training with: lambda=0.1, lr=0.188638, batch_size=0.010417, num_layers=0.012511
# Training with: lambda=0.1, lr=0.191531, batch_size=0.010422, num_layers=0.013858
# Training with: lambda=0.1, lr=0.184923, batch_size=0.010277, num_layers=0.015219
# Training with: lambda=0.1, lr=0.189329, batch_size=0.010367, num_layers=0.013819
# Training with: lambda=0.1, lr=0.191746, batch_size=0.010328, num_layers=0.013758
# Training with: lambda=0.1, lr=0.188211, batch_size=0.01029, num_layers=0.012934
# Training with: lambda=0.1, lr=0.188155, batch_size=0.010373, num_layers=0.013904
# Training with: lambda=0.1, lr=0.190857, batch_size=0.010235, num_layers=0.013995
# Training with: lambda=0.1, lr=0.18894, batch_size=0.010356, num_layers=0.014111
# Training with: lambda=0.1, lr=0.191895, batch_size=0.010258, num_layers=0.014314
# Training with: lambda=0.1, lr=0.188803, batch_size=0.010328, num_layers=0.013098
# Training with: lambda=0.1, lr=0.189848, batch_size=0.010349, num_layers=0.014047
# Training with: lambda=0.1, lr=0.191142, batch_size=0.010304, num_layers=0.01459
# Training with: lambda=0.1, lr=0.190524, batch_size=0.010303, num_layers=0.013941
# Training with: lambda=0.1, lr=0.189276, batch_size=0.010353, num_layers=0.014027
# Training with: lambda=0.1, lr=0.182995, batch_size=0.010203, num_layers=0.013486
# Training with: lambda=0.1, lr=0.189311, batch_size=0.010331, num_layers=0.013812
# Training with: lambda=0.1, lr=0.190452, batch_size=0.010251, num_layers=0.01397
# Training with: lambda=0.1, lr=0.190864, batch_size=0.01029, num_layers=0.013957
# Training with: lambda=0.1, lr=0.192308, batch_size=0.010271, num_layers=0.014777
# Training with: lambda=0.1, lr=0.189258, batch_size=0.010274, num_layers=0.013764
# Training with: lambda=0.1, lr=0.189495, batch_size=0.010218, num_layers=0.014101
# Training with: lambda=0.1, lr=0.193555, batch_size=0.010244, num_layers=0.014213
# Training with: lambda=0.1, lr=0.191096, batch_size=0.01026, num_layers=0.014038
# Training with: lambda=0.1, lr=0.189428, batch_size=0.010289, num_layers=0.0141
# Training with: lambda=0.1, lr=0.182574, batch_size=0.01017, num_layers=0.014098
# Training with: lambda=0.1, lr=0.191475, batch_size=0.010227, num_layers=0.013947
# Training with: lambda=0.1, lr=0.190249, batch_size=0.010259, num_layers=0.013958
# Training with: lambda=0.1, lr=0.191021, batch_size=0.010242, num_layers=0.013881
# Training with: lambda=0.1, lr=0.189684, batch_size=0.010277, num_layers=0.014487
# Training with: lambda=0.1, lr=0.18974, batch_size=0.010227, num_layers=0.014352
# Training with: lambda=0.1, lr=0.189972, batch_size=0.010157, num_layers=0.01406
# Training with: lambda=0.1, lr=0.191092, batch_size=0.010219, num_layers=0.013949
# Training with: lambda=0.1, lr=0.190223, batch_size=0.010238, num_layers=0.014006
# Training with: lambda=0.1, lr=0.190132, batch_size=0.010251, num_layers=0.014091
# Training with: lambda=0.1, lr=0.18664, batch_size=0.010279, num_layers=0.014328
# Training with: lambda=0.1, lr=0.191079, batch_size=0.010191, num_layers=0.014027
# Training with: lambda=0.1, lr=0.190148, batch_size=0.010263, num_layers=0.013952
# Training with: lambda=0.1, lr=0.190095, batch_size=0.010231, num_layers=0.013863
# Training with: lambda=0.1, lr=0.188638, batch_size=0.010267, num_layers=0.01393
# Training with: lambda=0.1, lr=0.190507, batch_size=0.010225, num_layers=0.014095
# Training with: lambda=0.1, lr=0.19024, batch_size=0.010252, num_layers=0.014018
# Training with: lambda=0.1, lr=0.188495, batch_size=0.010213, num_layers=0.013821
# Training with: lambda=0.1, lr=0.189754, batch_size=0.010259, num_layers=0.013985
# Training with: lambda=0.1, lr=0.190484, batch_size=0.010249, num_layers=0.013946
# Training with: lambda=0.1, lr=0.190234, batch_size=0.010334, num_layers=0.014255
# Training with: lambda=0.1, lr=0.190655, batch_size=0.010241, num_layers=0.014008
# Training with: lambda=0.1, lr=0.190097, batch_size=0.010265, num_layers=0.013949
# Training with: lambda=0.1, lr=0.189635, batch_size=0.010272, num_layers=0.013954
# Training with: lambda=0.1, lr=0.188748, batch_size=0.010261, num_layers=0.013671
# Training with: lambda=0.1, lr=0.19073, batch_size=0.010241, num_layers=0.013773
# Training with: lambda=0.1, lr=0.190347, batch_size=0.0103, num_layers=0.013925
# Training with: lambda=0.1, lr=0.189249, batch_size=0.010285, num_layers=0.01378
# Training with: lambda=0.1, lr=0.189738, batch_size=0.010277, num_layers=0.013963
# Training with: lambda=0.1, lr=0.190082, batch_size=0.010252, num_layers=0.013873
# Training with: lambda=0.1, lr=0.191913, batch_size=0.010293, num_layers=0.014058
# Training with: lambda=0.1, lr=0.190141, batch_size=0.010277, num_layers=0.013918
# Training with: lambda=0.1, lr=0.190072, batch_size=0.010266, num_layers=0.013947
# Training with: lambda=0.1, lr=0.189652, batch_size=0.010291, num_layers=0.013996
# Training with: lambda=0.1, lr=0.190442, batch_size=0.010259, num_layers=0.013625
# Training with: lambda=0.1, lr=0.190088, batch_size=0.010251, num_layers=0.013677
# Training with: lambda=0.1, lr=0.19036, batch_size=0.010301, num_layers=0.013883
# Training with: lambda=0.1, lr=0.190113, batch_size=0.010314, num_layers=0.013837
# Training with: lambda=0.1, lr=0.18977, batch_size=0.010271, num_layers=0.013936
# Training with: lambda=0.1, lr=0.189867, batch_size=0.010261, num_layers=0.01389
# Training with: lambda=0.1, lr=0.191803, batch_size=0.01025, num_layers=0.013911
# Training with: lambda=0.1, lr=0.189855, batch_size=0.010279, num_layers=0.013889
# Training with: lambda=0.1, lr=0.190059, batch_size=0.010267, num_layers=0.013946
# Training with: lambda=0.1, lr=0.189884, batch_size=0.010285, num_layers=0.014005
# Training with: lambda=0.1, lr=0.19119, batch_size=0.010259, num_layers=0.013607
# Training with: lambda=0.1, lr=0.18973, batch_size=0.010277, num_layers=0.01366
# Training with: lambda=0.1, lr=0.190099, batch_size=0.010269, num_layers=0.013915
# Training with: lambda=0.1, lr=0.190514, batch_size=0.010315, num_layers=0.013934
# Training with: lambda=0.1, lr=0.190049, batch_size=0.010264, num_layers=0.013936
# Training with: lambda=0.1, lr=0.189774, batch_size=0.010271, num_layers=0.013982
# Training with: lambda=0.1, lr=0.189293, batch_size=0.010239, num_layers=0.013872
# Training with: lambda=0.1, lr=0.189777, batch_size=0.01028, num_layers=0.013883
# Training with: lambda=0.1, lr=0.190053, batch_size=0.010267, num_layers=0.013946
# Training with: lambda=0.1, lr=0.190032, batch_size=0.010271, num_layers=0.014003
# Training with: lambda=0.1, lr=0.190001, batch_size=0.010265, num_layers=0.014104
# Training with: lambda=0.1, lr=0.189582, batch_size=0.010278, num_layers=0.013938
# Training with: lambda=0.1, lr=0.189949, batch_size=0.010253, num_layers=0.01397
# Training with: lambda=0.1, lr=0.190691, batch_size=0.01027, num_layers=0.013996
# Training with: lambda=0.1, lr=0.190192, batch_size=0.010264, num_layers=0.013937
# Training with: lambda=0.1, lr=0.18983, batch_size=0.010273, num_layers=0.013981
# Training with: lambda=0.1, lr=0.188359, batch_size=0.010247, num_layers=0.01386
# Training with: lambda=0.1, lr=0.190021, batch_size=0.010276, num_layers=0.013953
# Training with: lambda=0.1, lr=0.19005, batch_size=0.010267, num_layers=0.013946
# Training with: lambda=0.1, lr=0.190115, batch_size=0.010262, num_layers=0.013992
# Training with: lambda=0.1, lr=0.189435, batch_size=0.01027, num_layers=0.014159
# Training with: lambda=0.1, lr=0.189818, batch_size=0.010269, num_layers=0.014084
# Training with: lambda=0.1, lr=0.189918, batch_size=0.010252, num_layers=0.013986
# Training with: lambda=0.1, lr=0.190187, batch_size=0.010244, num_layers=0.013956
# Training with: lambda=0.1, lr=0.190203, batch_size=0.010267, num_layers=0.013944
# Training with: lambda=0.1, lr=0.189992, batch_size=0.01027, num_layers=0.013934
# Training with: lambda=0.1, lr=0.188306, batch_size=0.010269, num_layers=0.013897
# Training with: lambda=0.1, lr=0.190153, batch_size=0.010263, num_layers=0.013978
# Training with: lambda=0.1, lr=0.190048, batch_size=0.010267, num_layers=0.013946
# PSO - Best F1: 1.9985537565354292 Params: [0.190047, 0.010267, 0.013946]
# Training with: lambda=0.1, lr=0.2, batch_size=0.0078, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0077, num_layers=0.025
# Training with: lambda=0.1, lr=0.0, batch_size=0.0104, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.01
# Training with: lambda=0.1, lr=0.25, batch_size=0.0072, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.011, num_layers=0.015
# Training with: lambda=0.1, lr=0.2, batch_size=0.0103, num_layers=0.02
# Training with: lambda=0.1, lr=0.25, batch_size=0.0113, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0117, num_layers=0.025
# Training with: lambda=0.1, lr=0.1, batch_size=0.011, num_layers=0.025
# Training with: lambda=0.1, lr=0.25, batch_size=0.0103, num_layers=0.02
# Training with: lambda=0.1, lr=0.25, batch_size=0.0069, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0077, num_layers=0.025
# Training with: lambda=0.1, lr=0.25, batch_size=0.0104, num_layers=0.03
# Training with: lambda=0.1, lr=0.1, batch_size=0.0083, num_layers=0.04
# Training with: lambda=0.1, lr=0.05, batch_size=0.0106, num_layers=0.045
# Training with: lambda=0.1, lr=0.2, batch_size=0.0119, num_layers=0.025
# Training with: lambda=0.1, lr=0.25, batch_size=0.0063, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.007, num_layers=0.04
# Training with: lambda=0.1, lr=0.1, batch_size=0.0115, num_layers=0.035
# Training with: lambda=0.1, lr=0.05, batch_size=0.0072, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0101, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0076, num_layers=0.03
# Training with: lambda=0.1, lr=0.0, batch_size=0.0072, num_layers=0.02
# Training with: lambda=0.1, lr=0.05, batch_size=0.0095, num_layers=0.015
# Training with: lambda=0.1, lr=0.15, batch_size=0.0103, num_layers=0.03
# Training with: lambda=0.1, lr=0.05, batch_size=0.0082, num_layers=0.04
# Training with: lambda=0.1, lr=0.15, batch_size=0.0102, num_layers=0.04
# Training with: lambda=0.1, lr=0.0, batch_size=0.0102, num_layers=0.045
# Training with: lambda=0.1, lr=0.25, batch_size=0.0074, num_layers=0.035
# Training with: lambda=0.1, lr=0.0, batch_size=0.0092, num_layers=0.04
# Training with: lambda=0.1, lr=0.15, batch_size=0.0088, num_layers=0.015
# Training with: lambda=0.1, lr=0.1, batch_size=0.0075, num_layers=0.025
# Training with: lambda=0.1, lr=0.05, batch_size=0.0118, num_layers=0.045
# Training with: lambda=0.1, lr=0.0, batch_size=0.0114, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0105, num_layers=0.045
# Training with: lambda=0.1, lr=0.25, batch_size=0.0064, num_layers=0.01
# Training with: lambda=0.1, lr=0.05, batch_size=0.0107, num_layers=0.04
# Training with: lambda=0.1, lr=0.1, batch_size=0.0093, num_layers=0.015
# Training with: lambda=0.1, lr=0.0, batch_size=0.0113, num_layers=0.02
# Training with: lambda=0.1, lr=0.15, batch_size=0.0076, num_layers=0.045
# Training with: lambda=0.1, lr=0.05, batch_size=0.0075, num_layers=0.02
# Training with: lambda=0.1, lr=0.1, batch_size=0.0104, num_layers=0.035
# Training with: lambda=0.1, lr=0.15, batch_size=0.0086, num_layers=0.02
# Training with: lambda=0.1, lr=0.0, batch_size=0.0096, num_layers=0.02
# Training with: lambda=0.1, lr=0.1, batch_size=0.0065, num_layers=0.01
# Training with: lambda=0.1, lr=0.2, batch_size=0.0088, num_layers=0.02
# Training with: lambda=0.1, lr=0.1, batch_size=0.0096, num_layers=0.015
# Training with: lambda=0.1, lr=0.25, batch_size=0.0064, num_layers=0.015
# Training with: lambda=0.1, lr=0.05, batch_size=0.0062, num_layers=0.025
# Random Search - Best F1: 1.9903397848749447 Params: [0.15, 0.0102, 0.04]
